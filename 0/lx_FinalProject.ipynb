# %%
import CNN_model
import torch
import os
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import cv2
import pickle as pkl
from torch import Tensor
from joblib import dump, load
import submission
import pandas as pd

# %%
print(torch.cuda.is_available())
torch.cuda.empty_cache()
# Out:
# True
# True

# %%
cnn_model = CNN_model.CNN()

# %%
model = cnn_model.main()
# Out:
# Starting epoch 1
# Loss after mini-batch     1: 0.046
# Loss after mini-batch    11: 0.543
# Loss after mini-batch    21: 0.007
# Loss after mini-batch    31: 0.003
# Loss after mini-batch    41: 0.002
# Loss after mini-batch    51: 0.001
# Loss after mini-batch    61: 0.001
# Loss after mini-batch    71: 0.001
# Loss after mini-batch    81: 0.001
# Loss after mini-batch    91: 0.001
# Loss after mini-batch   101: 0.001
# Starting epoch 2
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.001
# Loss after mini-batch    31: 0.001
# Loss after mini-batch    41: 0.001
# Loss after mini-batch    51: 0.001
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 3
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 4
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 5
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 6
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.001
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 7
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 8
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 9
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.001
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 10
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 11
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 12
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.001
# Loss after mini-batch    61: 0.001
# Loss after mini-batch    71: 0.001
# Loss after mini-batch    81: 0.001
# Loss after mini-batch    91: 0.001
# Loss after mini-batch   101: 0.001
# Starting epoch 13
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 14
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 15
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 16
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 17
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 18
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.001
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 19
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 20
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 1
# Loss after mini-batch     1: 0.031
# Loss after mini-batch    11: 0.495
# Loss after mini-batch    21: 0.003
# Loss after mini-batch    31: 0.001
# Loss after mini-batch    41: 0.001
# Loss after mini-batch    51: 0.001
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 2
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.001
# Starting epoch 3
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.001
# Starting epoch 4
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 5
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 6
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.001
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 7
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 8
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 9
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 10
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 11
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 12
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 13
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 14
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 15
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 16
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 17
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 18
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 19
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000
# Starting epoch 20
# Loss after mini-batch     1: 0.000
# Loss after mini-batch    11: 0.000
# Loss after mini-batch    21: 0.000
# Loss after mini-batch    31: 0.000
# Loss after mini-batch    41: 0.000
# Loss after mini-batch    51: 0.000
# Loss after mini-batch    61: 0.000
# Loss after mini-batch    71: 0.000
# Loss after mini-batch    81: 0.000
# Loss after mini-batch    91: 0.000
# Loss after mini-batch   101: 0.000

# %%
model_scripted = torch.jit.script(model) # Export to TorchScript
model_scripted.save('res50_pretrained_model.pt') # Save

# %%
predictions = cnn_model.pred(model_name='res50_pretrained_model.pt')

# %%
dp = CNN_model.Data_Preprocessing()
data_test = CNN_model.load_images(path='C:\\Users\\14260\OneDrive\Desktop\CSE\data2022\Final Project_LX\\', isTrain = False)

# %%
img0_array_test, img1_array_test, img2_array_test, depth_array_test, field_id_array = dp.tensorToArray(data=data_test, isTrain=False)

# %%
normalized_depth_test = dp.depth_normalization(depth=depth_array_test)
normalized_img0_test = dp.img_normalization(img=img0_array_test)
new_img_test = dp.combine_image_depth(img=normalized_img0_test, depth=normalized_depth_test)
ready_img_test = dp.reshape_data(new_img_test)

# %%
testX = [ready_img_test, field_id_array]

# %%
dump(testX, 'preprocessed_testX.joblib')
# Out:
# ['preprocessed_testX.joblib']

# %%
sub = submission.Submission()
df = sub.submit()
# Out:
# True
# finished load data
# finished prep test data
# finished load model
# Batch Index: 0
# Batch Index: 5
# Batch Index: 10
# Batch Index: 15
# Batch Index: 20
# Batch Index: 25
# Batch Index: 30
# Batch Index: 35
# Batch Index: 40
# Batch Index: 45
# Batch Index: 50
# (849, 1)
# (849, 12)
# finished predict
# Written to csv file submission.csv
# all finished

# %%
print(df)
# Out:
#          ID  FINGER_POS_1  FINGER_POS_2  FINGER_POS_3  FINGER_POS_4  \
# 0     146.0      0.003810      0.028710      0.367810     -0.137438
# 1    1474.0     -0.095831     -0.081139      1.087295     -0.602162
# 2     213.0      0.000272      0.030800      0.434182     -0.144928
# 3    2831.0      0.004201     -0.026584      0.651392     -0.285644
# 4      26.0     -0.078199     -0.090665      1.002948     -0.566443
# ..      ...           ...           ...           ...           ...
# 844    27.0     -0.064308     -0.061771      0.935130     -0.505546
# 845  3226.0      0.027163      0.019813      0.330011     -0.084874
# 846   833.0     -0.028299     -0.048253      0.875631     -0.451766
# 847  3812.0      0.005183      0.004367      0.340948     -0.098336
# 848   601.0     -0.043630      0.030325      0.557237     -0.223620
#
#      FINGER_POS_5  FINGER_POS_6  FINGER_POS_7  FINGER_POS_8  FINGER_POS_9  \
# 0        0.178641      0.255948      0.195633     -0.031566      0.163750
# 1        0.781045      0.663996      0.493098     -0.064492      0.521005
# 2        0.227912      0.237063      0.242053     -0.041752      0.162364
# 3        0.422183      0.412188      0.363855     -0.022654      0.225068
# 4        0.792653      0.607416      0.449079     -0.087606      0.449044
# ..            ...           ...           ...           ...           ...
# 844      0.691629      0.577855      0.441929     -0.057446      0.387945
# 845      0.158999      0.209449      0.190940     -0.014954      0.071703
# 846      0.632193      0.517595      0.447723     -0.070826      0.387142
# 847      0.207584      0.200186      0.211503     -0.036987      0.123309
# 848      0.296914      0.352893      0.281664     -0.040094      0.160845
#
#      FINGER_POS_10  FINGER_POS_11  FINGER_POS_12
# 0         0.069734      -0.074862      -0.106242
# 1         0.354787      -0.253196      -0.326365
# 2         0.089776      -0.085608      -0.112677
# 3         0.195019      -0.110793      -0.193303
# 4         0.323179      -0.233455      -0.284382
# ..             ...            ...            ...
# 844       0.298023      -0.214259      -0.256833
# 845       0.068311      -0.056686      -0.102190
# 846       0.284466      -0.176446      -0.239080
# 847       0.090325      -0.071486      -0.087453
# 848       0.131143      -0.114483      -0.150312
#
# [849 rows x 13 columns]
